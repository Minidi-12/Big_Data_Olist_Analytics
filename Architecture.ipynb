# %%
components = [
    ('Data Source',    'Olist platform exports CSVs with real transaction data'),
    ('MongoDB Atlas',  'Cloud NoSQL DB storing JSON order documents'),
    ('Apache Spark',   'Distributed engine for cleaning, joining and analytics'),
    ('Spark MLlib',    'ML library training Random Forest on Grid Search method'),
    ('Dashboard',      'Databricks charts turning processed data into insights'),
]
 
print(f'{"Component":<20} {"Role"}')
print('-' * 70)
for name, role in components:
    print(f'{name:<20} {role}')
